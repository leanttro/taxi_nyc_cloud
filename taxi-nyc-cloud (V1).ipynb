# %%
pip install --upgrade pandas-gbq pyarrow
# Out:
# ...
#   Using cached pyarrow-21.0.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# ...
#    ---------------------------------------- 0.0/41.0 kB ? eta -:--:--
#    ---------------------------------------- 41.0/41.0 kB 1.9 MB/s eta 0:00:00
# Using cached pyarrow-21.0.0-cp311-cp311-win_amd64.whl (26.2 MB)
# ...
#    ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#    --------------- ------------------------ 61.4/160.8 kB 1.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 92.2/160.8 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 153.6/160.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 160.8/160.8 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/216.1 kB ? eta -:--:--
#    ----------- ---------------------------- 61.4/216.1 kB 1.1 MB/s eta 0:00:01
#    ------------------ ------------------- 102.4/216.1 kB 991.0 kB/s eta 0:00:01
# ...

# %%
pip install --upgrade pandas-gbq pyarrow
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
import requests
from io import BytesIO
import pymysql

# %%
URL_DO_ARQUIVO = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet"
response = requests.get(URL_DO_ARQUIVO)
df_completo = pd.read_parquet(BytesIO(response.content))

# %%
import pandas as pd

# Exemplo de como juntar os dados primeiro
# Supondo que seus dados venham de um arquivo parquet/csv
df_completo = pd.read_parquet(BytesIO(response.content))

# AGORA o seu DataFrame tem TODAS as colunas que você quer.
print("Colunas a serem enviadas:", df_completo.columns.tolist())

# Configurações do BigQuery
project_id = 'leanttro-projeto-taxi'
tabela_destino_bq = 'dados_analise.dados_brutos'

# Enviar o DataFrame COMPLETO para o BigQuery de uma vez
df_completo.to_gbq(
    destination_table=tabela_destino_bq,
    project_id=project_id,
    if_exists='replace' # Agora o 'replace' funciona, pois a "planta" está completa!
)
# Out:
# Colunas a serem enviadas: ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee']
# C:\Users\Desktop\AppData\Local\Temp\ipykernel_9032\3755959539.py:15: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   df_completo.to_gbq(
